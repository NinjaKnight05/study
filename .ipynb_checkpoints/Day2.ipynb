# %%
import pandas as pd

# %%
ser= pd.Series([23,45,65,68,97,76,24],)
ser
# Out:
# 0    23
# 1    45
# 2    65
# 3    68
# 4    97
# 5    76
# 6    24
# dtype: int64

# %%
ser>10
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# dtype: bool

# %%
(ser>10) & (ser<50)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
ser[(ser>10) & (ser<50)]
# Out:
# 0    23
# 1    45
# 6    24
# dtype: int64

# %%
ser[ser.between(30,70 ,inclusive='right')]
# Out:
# 1    45
# 2    65
# 3    68
# dtype: int64

# %%
ser[ser==45]
# Out:
# 1    45
# dtype: int64

# %%
ser==45
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
ser[ser==43]
# Out:
# Series([], dtype: int64)

# %%
ser[ser.isin([43])]
# Out:
# Series([], dtype: int64)

# %%
ser[ser.isin([97])]
# Out:
# 4    97
# dtype: int64

# %%
ser[ser.isin([97])].index
# Out:
# Index([4], dtype='int64')

# %%
ser.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
ser1=pd.Series({'name':'anurag','roll-no':23,'department':'cse'})
ser1
# Out:
# name          anurag
# roll-no           23
# department       cse
# dtype: object

# %%
ser2=pd.Series({'name':'anurag','roll-no':23,'department':'cse'},index=['name','marks'])
ser2
# Out:
# name     anurag
# marks       NaN
# dtype: object

# %%
ser2.index
# Out:
# Index(['name', 'marks'], dtype='object')

# %%
ser1.index
# Out:
# Index(['name', 'roll-no', 'department'], dtype='object')

# %%
ser2.values
# Out:
# array(['anurag', nan], dtype=object)

# %%
ser3= pd.Series([12,56,44,78,56,12,100,55,43])
ser3
# Out:
# 0     12
# 1     56
# 2     44
# 3     78
# 4     56
# 5     12
# 6    100
# 7     55
# 8     43
# dtype: int64

# %%
ser3.duplicated
# Out:
# <bound method Series.duplicated of 0     12
# 1     56
# 2     44
# 3     78
# 4     56
# 5     12
# 6    100
# 7     55
# 8     43
# dtype: int64>

# %%
ser3.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
[ser3.duplicated()]
# Out:
# [0    False
#  1    False
#  2    False
#  3    False
#  4     True
#  5     True
#  6    False
#  7    False
#  8    False
#  dtype: bool]

# %%
ser3[ser3.duplicated()]
# Out:
# 4    56
# 5    12
# dtype: int64

# %%
ser3.drop_duplicates()
# Out:
# 0     12
# 1     56
# 2     44
# 3     78
# 6    100
# 7     55
# 8     43
# dtype: int64

# %%
ser3.drop_duplicates(ignore_index=True)
# Out:
# 0     12
# 1     56
# 2     44
# 3     78
# 4    100
# 5     55
# 6     43
# dtype: int64

# %%
s1=pd.Series([14,56,77,88,100])
s2=pd.Series([1,5,7,88])

# %%
pd.concat((s1,s2))
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# 0      1
# 1      5
# 2      7
# 3     88
# dtype: int64

# %%
pd.concat((s1,s2,),ignore_index=True)
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# 5      1
# 6      5
# 7      7
# 8     88
# dtype: int64

# %%
s1.tolist()
# Out:
# [14, 56, 77, 88, 100]

# %%
def add2(a):
    return a+0

# %%
s1
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# dtype: int64

# %%
s1.map(add2)
# Out:
# 0     14
# 1     56
# 2     77
# 3     88
# 4    100
# dtype: int64
