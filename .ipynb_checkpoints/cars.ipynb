# %%
import pandas as pd

# %%
df=pd.read_csv("Used Car Dataset.csv")

# %%
df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
toyota=df[df['mileage(kmpl)'].isna()].index

# %%
df.loc[[513, 533, 589],:]
# Out:
#      Unnamed: 0             car_name registration_year insurance_validity  \
# 513         513  2011 Toyota Etios G            Dec-11      Comprehensive
# 533         533  2011 Toyota Etios G            Dec-11      Comprehensive
# 589         589  2011 Toyota Etios G            Jul-11      Comprehensive
#
#     fuel_type  seats  kms_driven   ownsership transmission manufacturing_year  \
# 513    Petrol      5       51710  First Owner       Manual               2011
# 533    Petrol      5       51710  First Owner       Manual               2011
# 589    Petrol      5       54214  First Owner       Manual               2011
#
#      mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 513            NaN         NaN             NaN         NaN             2.48
# 533            NaN         NaN             NaN         NaN             2.48
# 589            NaN         NaN             NaN         NaN             2.55

# %%
df.loc[toyota,"mileage(kmpl)"]=18

# %%
df.loc[toyota,"engine(cc)"]=1496

# %%
df.loc[toyota,"max_power(bhp)"]=986

# %%
df.loc[toyota,"torque(Nm)"]=132

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            1
# price(in lakhs)       0
# dtype: int64

# %%
df[df['torque(Nm)'].isna()].index
# Out:
# Index([462], dtype='int64')

# %%
df.loc[462]
# Out:
# Unnamed: 0                                      462
# car_name              2022 BMW X3 xDrive30i M Sport
# registration_year                            Feb-22
# insurance_validity                         Zero Dep
# fuel_type                                    Petrol
# seats                                             5
# kms_driven                                     8450
# ownsership                              First Owner
# transmission                              Automatic
# manufacturing_year                             2022
# mileage(kmpl)                                  19.0
# engine(cc)                                      5.0
# max_power(bhp)                                  5.0
# torque(Nm)                                      NaN
# price(in lakhs)                                71.9
# Name: 462, dtype: object

# %%
df.loc[462,'torque(Nm)']=350

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
fuel_diff=df[df["fuel_type"]=="Petrol"]

# %%
fuel_diff
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# 5              5                       2017 Honda Jazz 1.2 S i VTEC
# ...          ...                                                ...
# 1546        1546                              2018 Honda Jazz V CVT
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df["fuel_type"].value_counts()
# Out:
# fuel_type
# Petrol     1013
# Diesel      516
# CNG          22
# 5 Seats       2
# Name: count, dtype: int64

# %%
df["manufacturing_year"].value_counts()
# Out:
# manufacturing_year
# 2018                   236
# 2017                   190
# 2019                   184
# 2016                   133
# 2015                   133
# 2020                   122
# 2021                   119
# 2014                   103
# 2022                    90
# 2013                    51
# 2012                    50
# Power Steering          46
# 2023                    35
# 2011                    27
# 2010                    18
# 2009                    11
# Power Windows Front      2
# Air Conditioner          2
# 2007                     1
# Name: count, dtype: int64

# %%
df[df["engine(cc)"]<1000].value_counts().sum()
# Out:
# np.int64(200)

# %%
(df[df["engine(cc)"]>1000].value_counts )and(df[df["engine(cc)"]<2000 ].value_counts()).sum()
# Out:
# np.int64(1249)

# %%
# df[df['ownsership']=='First Owner'].value_counts().sum()

# %%
df['ownsership'].value_counts()
# Out:
# ownsership
# First Owner     1240
# Second Owner     240
# 1995 cc           24
# Third Owner       21
# 1498 cc            3
# 2993 cc            2
# 998 cc             2
# 1461 cc            2
# 1451 cc            2
# 1497 cc            2
# 2013               2
# Fifth Owner        2
# 999 cc             2
# 1998 cc            1
# 1950 cc            1
# 1996 cc            1
# 1199 cc            1
# 1248 cc            1
# 1197 cc            1
# 1984 cc            1
# 2999 cc            1
# 1968 cc            1
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual                 835
# Automatic              668
# 2017                    28
# 2014                     5
# 2011                     3
# 2023                     2
# 2020                     2
# 2021                     2
# 2022                     2
# Power Windows Front      2
# 2018                     2
# 2015                     1
# 2016                     1
# Name: count, dtype: int64
