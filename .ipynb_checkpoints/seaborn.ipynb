# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dg=sns.load_dataset('flights')

# %%
dg
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=dg,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
a=sns.lineplot(data=dg,x='year',y='passengers',hue='month')
a.set_title('Flights Passengers')
a.set_ylabel('Passengers')
a.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
sns.barplot(data=dg,x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=df,x='pclass',hue='age')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.pairplot(df)

# %%
sns.catplot(data=df,x='pclass',y='age',hue='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.catplot(data=df,x='pclass',y='age',hue='')
#
# File c:\Users\thaku\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2782, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779     elif x is not None and y is not None:
#    2780         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    2785         x=x, y=y, hue=hue, row=row, col=col, units=units, weight=weights
#    2786     ),
#    2787     order=order,
# ...

# %%
sns.pairplot(dg,hue='month')

# %%
sns.pairplot(dg,hue='year')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(data=df,x='pclass',y='age',hue='sex',)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.pairplot(df,hue='sex')

# %%
sns.catplot(data=df,x='age',y='age')

# %%
sns.displot(data=dg,x='year',y='passengers',hue='month')

# %%
sns.dogplot()

# %%
sns.boxplot(data=dg,x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.ecdfplot()
# Out:
# <Axes: >

# %%
sns.pointplot(data=dg,x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.relplot(data=df,x='pclass',y='age',hue='sex')

# %%
sns.violinplot(data=dg,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.swarmplot(data=dg,x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
dg.pivot_table(values='passengers',index='month',columns='year')
# Out:
# C:\Users\thaku\AppData\Local\Temp\ipykernel_27864\2104829772.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dg.pivot_table(values='passengers',index='month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...
