# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('neet_data.csv')

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.sort_values('retweet_count',ascending=False)
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 17546  2020-10-31 13:04:10              0   Twitter for iPhone
# 17547  2020-10-31 13:03:56              0  Twitter for Android
# 17548  2020-10-31 13:03:38              0  Twitter for Android
# 17550  2020-10-31 13:02:40              0      Twitter Web App
# 47359  2020-10-30 15:38:30              0   Twitter for iPhone
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
df.sort_values('retweet_count',ascending=False).head(10)
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# 16277  2020-10-25 14:14:37         137480  Twitter for Android
# 37849  2020-11-04 23:18:55         137374      Twitter Web App
# 37640  2020-11-05 04:09:52         137367  Twitter for Android
# 37071  2020-11-05 12:17:30         137367   Twitter for iPhone
# 14527  2020-10-26 13:28:21         129080  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# 33262  1099388669448867842                           Neet\xf0\x9f\x83\x8fPeet
# ...

# %%
all=df.sort_values('retweet_count',ascending=False).head(10)

# %%
first=all['retweet_count']

# %%
first
# Out:
# 32860    614304
# 33262    581097
# 35111    381458
# 32585    204348
# 38044    192350
# 16277    137480
# 37849    137374
# 37640    137367
# 37071    137367
# 14527    129080
# Name: retweet_count, dtype: int64

# %%
print('TOP 10 Retweet sum is XXXXXX')
first.sum()
# Out:
# TOP 10 Retweet sum is XXXXXX
# np.int64(2652225)

# %%
android_count=df[df.loc[:,'source'].str.contains('Android',na=False)]

# %%
android_count
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# 5      2020-10-31 14:07:29             80  Twitter for Android
# 6      2020-10-31 14:06:34            141  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 3      1085818329816883201                 The Rus
# 4      1227501071490113537            Sakshi Yadav
# ...

# %%
df.loc[df['user_follower_count'].idxmax(),['user_name','user_location','user_follower_count']]
# Out:
# user_name                  NDTV
# user_location             India
# user_follower_count    13934355
# Name: 44355, dtype: object

# %%
df['followers_friend_ratio']=df['user_follower_count'] / df['user_friends_count']

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.isna().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# followers_friend_ratio      147
# dtype: int64

# %%
null_contains=df[df['user_description'].isna()].index

# %%
null_contains
# Out:
# Index([    0,     3,    10,    18,    22,    27,    31,    43,    48,    53,
#        ...
#        47318, 47324, 47329, 47341, 47353, 47357, 47363, 47364, 47370, 47378],
#       dtype='int64', length=10871)

# %%
df.loc[null_contains,'user_description']='Twitter'

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.isna().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description              0
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# followers_friend_ratio      147
# dtype: int64

# %%
df.drop(['source','user_name','user_location','user_url','followers_friend_ratio'],axis=1,inplace=True)

# %%
df.insert(3,'is_allow','True')

# %%
df
# Out:
#                 created_at  retweet_count              user_id is_allow  \
# 0      2020-10-31 14:10:28            141  1250294694937915394     True
# 1      2020-10-31 14:10:11              1             57059492     True
# 2      2020-10-31 14:09:48            141           1016022678     True
# 3      2020-10-31 14:09:41            141  1085818329816883201     True
# 4      2020-10-31 14:09:22              0  1227501071490113537     True
# ...                    ...            ...                  ...      ...
# 47376  2020-10-30 15:29:35              0  1168840190426632192     True
# 47377  2020-10-30 15:29:35           1700           1696615807     True
# 47378  2020-10-30 15:28:59            167  1313330869113745413     True
# 47379  2020-10-30 15:28:37            270  1161551282995388416     True
# 47380  2020-10-30 15:28:14              0  1211810532006612992     True
#
#                                         user_description  user_follower_count  \
# ...

# %%
df.drop('tweet',axis=1,inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count              user_id is_allow  \
# 0      2020-10-31 14:10:28            141  1250294694937915394     True
# 1      2020-10-31 14:10:11              1             57059492     True
# 2      2020-10-31 14:09:48            141           1016022678     True
# 3      2020-10-31 14:09:41            141  1085818329816883201     True
# 4      2020-10-31 14:09:22              0  1227501071490113537     True
# ...                    ...            ...                  ...      ...
# 47376  2020-10-30 15:29:35              0  1168840190426632192     True
# 47377  2020-10-30 15:29:35           1700           1696615807     True
# 47378  2020-10-30 15:28:59            167  1313330869113745413     True
# 47379  2020-10-30 15:28:37            270  1161551282995388416     True
# 47380  2020-10-30 15:28:14              0  1211810532006612992     True
#
#                                         user_description  user_follower_count  \
# ...

# %%
dates=df['created_at'].str

# %%
dates

# %%
dates[0:4]
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 47376    2020
# 47377    2020
# 47378    2020
# 47379    2020
# 47380    2020
# Name: created_at, Length: 47381, dtype: object

# %%
dates[5:7]
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 47376    10
# 47377    10
# 47378    10
# 47379    10
# 47380    10
# Name: created_at, Length: 47381, dtype: object
