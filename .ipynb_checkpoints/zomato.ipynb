# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("zomato_dataset.csv")

# %%
df
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
df.isna().sum()
# Out:
# Restaurant Name        0
# Dining Rating      32236
# Delivery Rating     1280
# Dining Votes           0
# Delivery Votes         0
# Cuisine                0
# Place Name             0
# City                   0
# Item Name              0
# Best Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %%
ratings=df[df['Delivery Rating'].isna()].index

# %%
ratings
# Out:
# Index([  2340,   2341,   2342,   2343,   2344,   2345,   2346,   2347,   2348,
#          2349,
#        ...
#        122695, 122696, 122697, 122698, 122699, 122700, 122701, 122702, 122703,
#        122704],
#       dtype='int64', length=1280)

# %%
rating=df['Delivery Rating'].median()
rating
# Out:
# np.float64(4.0)

# %%
df.loc[ratings,"Delivery Rating"]=rating

# %%
df.isna().sum()
# Out:
# Restaurant Name        0
# Dining Rating      32236
# Delivery Rating        0
# Dining Votes           0
# Delivery Votes         0
# Cuisine                0
# Place Name             0
# City                   0
# Item Name              0
# Best Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %%
dining=df[df['Dining Rating'].isna()].index

# %%
dining
# Out:
# Index([  1229,   1230,   1231,   1232,   1233,   1234,   1235,   1236,   1237,
#          1238,
#        ...
#        123314, 123315, 123316, 123317, 123318, 123319, 123320, 123321, 123322,
#        123323],
#       dtype='int64', length=32236)

# %%
din=df['Dining Rating'].median()

# %%
din
# Out:
# np.float64(3.9)

# %%
df['Dining Rating'].min()
# Out:
# np.float64(2.5)

# %%
df.loc[dining,'Dining Rating']=din

# %%
df.isna().sum()
# Out:
# Restaurant Name        0
# Dining Rating          0
# Delivery Rating        0
# Dining Votes           0
# Delivery Votes         0
# Cuisine                0
# Place Name             0
# City                   0
# Item Name              0
# Best Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %%
sellidnx=df[df["Best Seller"].isna()].index

# %%
sellidnx
# Out:
# Index([     2,      8,      9,     10,     14,     19,     21,     23,     24,
#            25,
#        ...
#        123645, 123646, 123647, 123648, 123649, 123651, 123652, 123653, 123654,
#        123655],
#       dtype='int64', length=95715)

# %%
df['Best Seller'].unique()
# Out:
# array(['BESTSELLER', nan, 'MUST TRY', "CHEF'S SPECIAL", 'SEASONAL',
#        'Not eligible for coupons', 'VEGAN', 'Not on Pro', 'SPICY', 'NEW',
#        'GLUTEN FREE', 'DAIRY FREE', 'FODMAP FRIENDLY',
#        'Eggless available'], dtype=object)

# %%
df.loc[sellidnx,'Best Seller']='no'

# %%
df.isna().sum()
# Out:
# Restaurant Name    0
# Dining Rating      0
# Delivery Rating    0
# Dining Votes       0
# Delivery Votes     0
# Cuisine            0
# Place Name         0
# City               0
# Item Name          0
# Best Seller        0
# Votes              0
# Prices             0
# dtype: int64

# %%
df
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
px.scatter(data_frame=df,x='Dining Rating',y='Dining Votes',color='Dining Votes')

# %%
px.scatter(data_frame=df,x="Delivery Rating",y ="Delivery Votes")

# %%
sns.pairplot(df)

# %%
df[(df["Delivery Rating"]>4)&(df["Cuisine "]=='Pizza') ]
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 2357       MS Bakery & Sweets            3.9              4.2             0
# 2358       MS Bakery & Sweets            3.9              4.2             0
# 2359       MS Bakery & Sweets            3.9              4.2             0
# 2360       MS Bakery & Sweets            3.9              4.2             0
# 2361       MS Bakery & Sweets            3.9              4.2             0
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
df[(df["Dining Rating"]>4)&(df["Cuisine "]=='Pizza') ]
# Out:
#        Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 35936     Little Italy            4.4              3.8           349
# 35937     Little Italy            4.4              3.8           349
# 35938     Little Italy            4.4              3.8           349
# 35939     Little Italy            4.4              3.8           349
# 35940     Little Italy            4.4              3.8           349
# ...                ...            ...              ...           ...
# 121814         Wafflez            4.1              4.1           171
# 121815         Wafflez            4.1              4.1           171
# 121816         Wafflez            4.1              4.1           171
# 121817         Wafflez            4.1              4.1           171
# 121818         Wafflez            4.1              4.1           171
#
#         Delivery Votes Cuisine     Place Name      City  \
# 35936                0    Pizza  Nungambakkam   Chennai
# ...

# %%
df[(df["Dining Votes"]>400)&(df["Delivery Rating"])].value_counts().drop_duplicates
# Out:
# <bound method Series.drop_duplicates of Restaurant Name    Dining Rating  Delivery Rating  Dining Votes  Delivery Votes  Cuisine    Place Name       City     Item Name                      Best Seller  Votes  Prices
# Domino's Pizza     3.9            3.9              563           0               Fast Food  Entally          Kolkata  Kosha Chicken Pizza            no           0      359.0     6
#                                                                                                                       Pepper Barbecue Chicken Pizza  BESTSELLER   103    259.0     6
#                                                                                                                       Farmhouse Pizza                BESTSELLER   69     269.0     6
#                                                                                                                       Chicken Dominator Pizza        BESTSELLER   70     369.0     6
# ...

# %%
vote=df["Votes"].sort_values(ascending=False).head(30)

# %%
px.pie(vote,values=df.loc[vote,"Votes"],names=df.loc[vote,"Restaurant Name"],title="Top 12 Restaurant Names")

# %%
df["Best Seller"].unique()
# Out:
# array(['BESTSELLER', 'no', 'MUST TRY', "CHEF'S SPECIAL", 'SEASONAL',
#        'Not eligible for coupons', 'VEGAN', 'Not on Pro', 'SPICY', 'NEW',
#        'GLUTEN FREE', 'DAIRY FREE', 'FODMAP FRIENDLY',
#        'Eggless available'], dtype=object)

# %%
sns.swarmplot(data=df,x=df["Prices"].head(20),y=df["Votes"].head(300))
# Out:
# <Axes: xlabel='Prices', ylabel='Votes'>

# %%
total= df[df["Best Seller"].isin(["CHEF'S SPECIAL", "BESTSELLER","MUST TRY"])&(df["Votes"]).head(40)]
total
# Out:
# C:\Users\thaku\AppData\Local\Temp\ipykernel_3068\1052196855.py:1: FutureWarning:
#
# Operation between Series with different indexes that are not of numpy boolean or object dtype will no longer return a numpy boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#    Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 1       Doner King            3.9              4.2            39
# 3       Doner King            3.9              4.2            39
# 4       Doner King            3.9              4.2            39
# 6       Doner King            3.9              4.2            39
# 7       Doner King            3.9              4.2            39
# 11      Doner King            3.9              4.2            39
# 12      Doner King            3.9              4.2            39
# 13      Doner King            3.9              4.2            39
# 16      Doner King            3.9              4.2            39
# ...

# %%
plt.bar(data=total,x="Best Seller",height="Votes",width=0.4,color=["Orange","red"],)
# item=df["Votes"].value_counts(ascending=False).head(10).drop_duplicates

# item
# Out:
# <BarContainer object of 14 artists>

# %%
itemss = df["Votes"].sort_values(ascending=False).head(10).drop_duplicates().index
itemss
# Out:
# Index([12417, 11146, 6135, 11145, 12461], dtype='int64')

# %%
best=df.loc[itemss,:]
best
# Out:
#         Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 12417            Mehfil            4.1              4.0             0
# 11146          Bawarchi            4.2              4.1             0
# 6135   Lucky Restaurant            4.1              4.0             0
# 11145          Bawarchi            4.2              4.1             0
# 12461            Mehfil            4.1              4.0             0
#
#        Delivery Votes      Cuisine     Place Name        City  \
# 12417               0  North Indian   Narayanguda   Hyderabad
# 11146               0      Desserts   RTC X roads   Hyderabad
# 6135                0     Beverages  Saroor Nagar   Hyderabad
# 11145               0      Desserts   RTC X roads   Hyderabad
# 12461               0  North Indian   Narayanguda   Hyderabad
#
#                     Item Name Best Seller  Votes  Prices
# 12417  Chicken Biryani Single  BESTSELLER   9750   130.0
# ...

# %%
px.bar(data_frame=best,x="Item Name",y="Votes",title="Votes by Per Item")

# %%
popularity = df["Delivery Rating"].sort_values(ascending=False).head(100000).drop_duplicates().index
popularity
# Out:
# Index([6788, 113350, 53844, 117283, 102415, 419, 98222, 180, 49302, 72], dtype='int64')

# %%
df.loc[popularity,:]
# Out:
#                                     Restaurant Name  Dining Rating  \
# 6788                                  Subhan Bakery            3.9
# 113350  Balaram Mullick & Radharaman Mullick Sweets            3.3
# 53844                   Jal Mahal Ice Cream Parlour            4.1
# 117283                                  Rolls Mania            3.9
# 102415                                Madhurima Veg            4.0
# 419                           Siddique Kabab Centre            4.4
# 98222                                  TKS Iyengars            3.4
# 180                        Crystal Restaurant & Bar            4.2
# 49302                                 Punjabi Tadka            3.8
# 72                                        Taco Bell            4.3
#
#         Delivery Rating  Dining Votes  Delivery Votes      Cuisine   \
# 6788                4.6            12               0        Bakery
# 113350              4.5             6               0         Pizza
# ...

# %%
px.pie(data_frame=popularity,values=df.loc[popularity,"Delivery Rating"],names=df.loc[popularity,"Item Name"],title="Most Popular")

# %%
cusin = df["Votes"].sort_values(ascending=False).head(10).drop_duplicates().index
cusin
# Out:
# Index([12417, 11146, 6135, 11145, 12461], dtype='int64')

# %%
df.loc[cusin,:]
# Out:
#         Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 12417            Mehfil            4.1              4.0             0
# 11146          Bawarchi            4.2              4.1             0
# 6135   Lucky Restaurant            4.1              4.0             0
# 11145          Bawarchi            4.2              4.1             0
# 12461            Mehfil            4.1              4.0             0
#
#        Delivery Votes      Cuisine     Place Name        City  \
# 12417               0  North Indian   Narayanguda   Hyderabad
# 11146               0      Desserts   RTC X roads   Hyderabad
# 6135                0     Beverages  Saroor Nagar   Hyderabad
# 11145               0      Desserts   RTC X roads   Hyderabad
# 12461               0  North Indian   Narayanguda   Hyderabad
#
#                     Item Name Best Seller  Votes  Prices
# 12417  Chicken Biryani Single  BESTSELLER   9750   130.0
# ...

# %%
plt.bar(data=cusin,x=df.loc[cusin,"Cuisine "],height=df.loc[cusin,"Votes"],width=0.2,color=["orange"],edgecolor="blue")
# Out:
# <BarContainer object of 5 artists>

# %%
px.pie(data_frame=popularity,values=df.loc[popularity,"Votes"],names=df.loc[popularity,"Item Name"],title="Most Popular Menu Items")

# %%
px.line(data_frame=best,x="Item Name",y="Votes",title="High In Demand")

# %%
low = df[df["Votes"]<10].head(30)
low
# Out:
#    Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 10      Doner King            3.9              4.2            39
# 12      Doner King            3.9              4.2            39
# 13      Doner King            3.9              4.2            39
# 14      Doner King            3.9              4.2            39
# 21      Doner King            3.9              4.2            39
# 22      Doner King            3.9              4.2            39
# 23      Doner King            3.9              4.2            39
# 24      Doner King            3.9              4.2            39
# 25      Doner King            3.9              4.2            39
# 26      Doner King            3.9              4.2            39
# 29      Doner King            3.9              4.2            39
# 31      Doner King            3.9              4.2            39
# 32      Doner King            3.9              4.2            39
# ...

# %%
px.bar(data_frame=low,x="Item Name",y="Votes",color="Votes")
