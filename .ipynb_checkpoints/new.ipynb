# %%
# %pip install tensorflow==2.17.0
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 0.4/385.2 MB 7.6 MB/s eta 0:00:51
#    ---------------------------------------- 0.6/385.2 MB 7.4 MB/s eta 0:00:53
#    ---------------------------------------- 0.7/385.2 MB 5.8 MB/s eta 0:01:07
#    ---------------------------------------- 0.8/385.2 MB 5.2 MB/s eta 0:01:15
#    ---------------------------------------- 1.0/385.2 MB 5.1 MB/s eta 0:01:16
#    ---------------------------------------- 1.0/385.2 MB 5.1 MB/s eta 0:01:16
#    ---------------------------------------- 1.0/385.2 MB 5.1 MB/s eta 0:01:16
#    ---------------------------------------- 1.0/385.2 MB 5.1 MB/s eta 0:01:16
#    ---------------------------------------- 1.0/385.2 MB 5.1 MB/s eta 0:01:16
# ...

# %%
import tensorflow as tf

# %%
print(tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from 'c:\\Users\\thaku\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>
